# %% [markdown]
# <a href="https://colab.research.google.com/github/nucleosight/nlp/blob/main/Dataset_Access_Common_Voice_Urdu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Corpus sources

# %%
pip install datasets

# %%
from datasets import load_dataset
from huggingface_hub import login
login(token = "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")
ds = load_dataset("mozilla-foundation/common_voice_17_0", "ur", split = 'train', streaming = 'true', trust_remote_code= 'true')
ds = ds.remove_columns(['client_id',  "up_votes",
    "down_votes",
    "age",
    "gender",
    "accent",
    "locale",
    "segment",
    "variant"])

# %%
# prompt: save all rows of huggingface streaming datsets as a pandas dataframe

import pandas as pd

df = pd.DataFrame()
for row in ds:
  df = pd.concat([df, pd.DataFrame([row])], ignore_index=True)

print(df)

# %%
# @title Display a sample {"run":"auto","display-mode":"form"}
row_index = 1092 # @param {"type":"slider","min":0,"max":5368,"step":1}
try:
  row = df.iloc[row_index]
  text = row['sentence']
  audio_data = row['audio']['array']

  print(f"Text: {text}")
  display(Audio(audio_data, rate=row['audio']['sampling_rate']))

except IndexError:
  print("Row index out of range.")
# Out:
# Text: یقینااس فیصلے کے دور رس اثرات اثرات مرتب ہو ں گے۔
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
